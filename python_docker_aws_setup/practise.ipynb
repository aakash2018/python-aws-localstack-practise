# %%
for i in range(5):
    print(" *"*(5-i))
# Out:
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *

# %%
for i in range(5):
    print(" *" * (i + 1))
# Out:
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *

# %%
for i in range(5):
    print((5-i-1) * " " + (i + 1) * " *")
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *

# %%
for i in range(5):
    print((5-i-1) * "  " + (2*i + 1) * " *")
# Out:
#          *
#        * * *
#      * * * * *
#    * * * * * * *
#  * * * * * * * * *

# %%
for i in range(5):
    print("  "*(i+1) + "* "*(5-i))
# Out:
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *

# %%
for i in range(5):
    print(" "*(i+1) + " *"*(5-i))
# Out:
#   * * * * *
#    * * * *
#     * * *
#      * *
#       *

# %%
for i in range(5):
    print(" * " * (5))
# Out:
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *

# %%
n=5

for i in range(n):
    print(" " * (n - i - 1) + "*" * (2 * i + 1))

for i in range(n):
    print(" " * (i + 1) + "*" * (2 * (n - 1 - i) - 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
n=5

for i in range(n):
    print("*" * (n - i) + " " * (2 * i + 1))

for i in range(n):
    print("*" * (i + 1) + " " * (2 * (n - 1 - i) - 1))
# Out:
# *****
# ****
# ***
# **
# *
# *
# **
# ***
# ****
# *****
